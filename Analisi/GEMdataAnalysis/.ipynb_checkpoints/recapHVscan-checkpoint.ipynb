# %% [markdown]
# # Analysis of HVscan of 2/3 GEM layer
# Nel seguente script vengono confrontati i risultati ottenuti dall'analisi effettuata sui dati per 2 strati GEM e 3 strati GEM.

# %% [markdown]
# ## 2 GEM layer in autotrigger mode
# E' stata eseguita l'analisi degli istogrammi di carica per i dati ottenuti in autotrigger.

# %% [markdown]
# Per ciascun dataset è stato eseguito un fit dell'istogramma ottenuto con una gaussiana intorno a picco per valutarne la $\sigma$, sono quindi stati graficati i valori medi di carica depositata in funzione della tensione $\Delta V_{GEM}$ tra gli strati del detector ottenendo il seguente andamento

# %%
from IPython.display import Image

# %%
Image("CaricaVsHV2gem.png")

# %% [markdown]
# Le incertezze sono date da $\frac{\sigma}{\sqrt{N_{dati}}}$

# %% [markdown]
# E' stato quindi calcolata la carica media depositata dal fondo integrando per i primi $300$ $ns$ ottenendo delle distribuzioni gaussiane centrate intorno a valori vicini allo 0. Per un confronto più agevole sono stati graficati come nel caso precedente tali risultati in funzione della tensione di GEM ottenendo

# %%
Image("CaricaVsHVbkgnd2gem.png")

# %% [markdown]
# le incertezze sono state calcolate in modo analogo al caso precedente

# %% [markdown]
# ## 2 GEM layer with trigger on Cosmic-Rays
# Eseguendo la stessa analisi ma con trigger sui cosmici si osserva lo stesso andamento crescente del caso in autotrigger

# %%
Image('CaricaVsHV2gemCosmici.png')

# %% [markdown]
# ## 3 GEM layer in autotrigger mode
# Dopo aver riparato il 3o strato GEM sono state eseguite nuovamente le misure in autotrigger ottenendo il seguente andamento

# %%
Image('CaricaVsHV.png')

# %% [markdown]
# Ovviamente un andamento del genere non ha senso, è stato comunque provato un nuovo scan di tensioni GEM cambiando la soglia di acquisizione da -10 mV a -20 mV, ottenendo lo stesso andamento ma con il massimo spostato alla tensione di 390 V.

# %% [markdown]
# Questo ha portato a pensare a una possibile dipendenza dalla soglia di acquisizione che, unita al fatto che a tensioni alte la gem potrebbe fare delle micro scariche, permetterebbe di giustificare l'andamento riscontrato

# %% [markdown]
# Si è quindi proceduto comunque all'analisi del fondo, come riportato di seguito, e dello scan HV con trigger sui cosmici.

# %%
Image('CaricaVsHVbkgnd.png')

# %% [markdown]
# ## 3 GEM layer with trigger on Cosmic-Rays
# Dai dati ottenuti con trigger sui cosmici si riscontra il seguente andamento della carica in funzione della tensione GEM

# %%
Image('CaricaVsHVCosmici.png')
