# %% [markdown]
# # HVscanGEM
# Questo programma permette di estrarre i dati del Ch4 di ciascun dataset $.root$ relativo allo scan HV in cui viene variata la tensione tra i vari strati GEM.

# %%
import ROOT as root
import numpy as np
import matplotlib.pyplot as plt

from ROOT import TMath , TF1, TH1F
import scipy.stats as st 

#from ROOT import TMath , TCanvas , TGraph , TH1D

fileNumberStart = 360

#un cambio di nome inutile...è solo più corto da scrivere
number = fileNumberStart

#definisco degli array in cui salvare dinamicamente i valori da graficare
means = []
errors = []
hv = []


while(number <= 450): #ciclo che permette di aprire tutti i file in sequenza
    filename = '../../../Data/PMTgem/selfPMTgemNew_%s.root'%(str(number))
    print("APERTURA di: " + filename)
    
    fileROOT = root.TFile(filename)#"chargeDataBlu.root") #nome del rootfile
    tree = fileROOT.Get("t1") #nome del datatree

    n = 1024
    nCh = 4
    nDat = n*nCh #numero dati per evento...vengono salvati in riga tutti i canali
    nEvts = tree.GetEntries() #numero di eventi
    
    wave = np.zeros((nEvts,nDat))
    time = np.zeros((nEvts,nDat))
    
    print('...(%d) Caricamento Dati...'%(number))
    i=0
    for dat in tree:
        wave[i] = np.array(dat.wave_array)
        time[i] = np.array(dat.time_array)
        i = i+1    

    print('...Caricamento Dati Completato!...\n\n')

    waveCh1 = np.zeros((nEvts,n))
    waveCh2 = np.zeros((nEvts,n))
    waveCh3 = np.zeros((nEvts,n))
    waveCh4 = np.zeros((nEvts,n))

    timeCh1 = np.zeros((nEvts,n))
    timeCh2 = np.zeros((nEvts,n))
    timeCh3 = np.zeros((nEvts,n))
    timeCh4 = np.zeros((nEvts,n))
    
    print('...(%d) Organizzazione Dati...'%(number))
    
    for i in range(nEvts):
        for j in range(nDat):
            if j < nDat/4:
                waveCh1[i][j] = wave[i][j]
                timeCh1[i][j] = time[i][j]
            elif j >= nDat/4 and j < nDat/2:
                waveCh2[i][j-n] = wave[i][j]
                timeCh2[i][j-n] = time[i][j]
            elif j >= nDat/2 and j < nDat*3/4:
                waveCh3[i][j-2*n] = wave[i][j]
                timeCh3[i][j-2*n] = time[i][j]
            elif j >= nDat*3/4: 
                waveCh4[i][j-3*n] = wave[i][j]
                timeCh4[i][j-3*n] = time[i][j]

    print('...Organizzazione Completata...\n\n')
    j = 0
    print('...Controllo Eventi Da Scartare...')
    for i in range(nEvts):
        if min(waveCh4[i]) < -110 and waveCh4[i].argmin() < 5: 
            #print(i , waveCh4[i].argmin() , timeCh4[i][waveCh4[i].argmin()])
            j = j+1
    print('...Eventi Scartati da ' + filename + ': ' + str(j) + '/' + str(nEvts) + '\n\n')
    
    print('...(%d) Rimozione Piedistallo...'%(number))
    for i in range(nEvts):
        waveCh4[i] = waveCh4[i]-np.mean(waveCh4[i][100:200])
    print("...Piedistallo Rimosso...\n\n")
    
    print('...(%d) Calcolo del Segnale in Corrente e Rimozione degli Eventi Da Scartare...'%(number))
    waveCh4A = np.zeros((nEvts-j,n))
    R = 50 #resistenza in Ohm

    k=0
    for i in np.arange(1,nEvts):
        #butto gli eventi con il picco strano
        if min(waveCh4[i]) >= -110 or (min(waveCh4[i])< -110  and waveCh4[i].argmin() != 1):
            #if min(waveCh4[i][500:750]) < -20:
            waveCh4A[k] = waveCh4[i]/R #conversione dati Tensione -> dati Corrente
            k = k+1
        else: 1 
            #print(min(waveCh4[i]) , waveCh4[i].argmin() , i) #check

    print('...Calcolo & Rimozione Completati...\n\n')
            
    print('...CONTROLLO -> Eventi Eliminati da ' + filename + ' ' + str(nEvts - k) + '\n\n')#check
    
    print('...(%d) Calcolo dell\'Integrale di Carica...'%(number))
    integral = np.zeros(k)

    #Eseguo l'Integrale
    for i in range(k):
        #if(min(waveCh4A[i][500:750]) < -20):
        integral[i] = sum(-waveCh4A[i][500:750])

    print('...Calcolo Eseguito...\n\n')

    #c = TCanvas()
    #g = TGraph(x.size, x.astype(np.double),y.astype(np.double))
    #fit = g.Fit("gaus" , "S")
    
    #g.Draw("AP")
   
    #----FIT e GRAFICO ISTOGRAMMA----

    xmin = min(integral)
    
    h1 = TH1F( "h1", "Istogramma di Carica $PMT_{gem}$ a %d V ; Charge [pC] ; Counts "%(number), 100, xmin, 50 )
    for i in integral:
        h1.Fill(i)
        
    xmax = h1.GetBinCenter(h1.GetMaximumBin())#max(integral)#  #è la x del max dell'istogramma
    
    l = np.linspace(xmin , xmax+3 , len(integral))
    func = TF1("fitF" , "gaus" , xmin , xmax+3)
    func.SetParLimits(1 , xmax-1 , xmax+1) 
    #func.SetParLimits(0 , h1.GetMaximum() , h1.GetMaximum())
    
    h1.Fit("fitF" , "R")
    
    #uso la normale definita in scipy usando i parametri estratti dal fit
    pdf = st.norm.pdf(l , func.GetParameter(1) , func.GetParameter(2)) 

    from rootplot import root2matplotlib as r2m
    
    histo1 = r2m.Hist(h1) #permette di leggere l'istogramma già riempito da root
    histo1.hist()#histtype = 'step' , fill = False) #fa l'istogramma
    plt.plot(l , pdf*func.GetParameter(0)/max(pdf) , label = 'Fit' , color = 'r') 
    plt.grid()
    #plt.xlim((xmin,10))
    plt.legend()
    histo1.show_titles()
    #plt.xlabel('Charge [pC]')
    #plt.ylabel('Counts')
    #plt.title(')
    plt.show()

    #----------------------------
    
    print('...(%d) Calcolo del Valore Medio e Salvataggio...'%(number))
    
    print(np.mean(integral) , func.GetParameter(1))

    means.append(np.mean(integral))#func.GetParameter(1))#
    errors.append(func.GetParameter(2)/np.sqrt(len(integral)))#func.GetParError(1))#
    hv.append(number)
    
    
    
    
    
#fine analisi
    print('---- Analisi su ' + filename + ' COMPLETATA! ----\n\n')
    number += 10
    
print('----- ANALISI GENERALE CONCLUSA!!!! ------')
# Out:
# APERTURA di: ../../../Data/PMTgem/selfPMTgemNew_360.root
# ...(360) Caricamento Dati...
# ...Caricamento Dati Completato!...
#
#
# ...(360) Organizzazione Dati...
# ...Organizzazione Completata...
#
#
# ...Controllo Eventi Da Scartare...
# ...Eventi Scartati da ../../../Data/PMTgem/selfPMTgemNew_360.root: 5/1000
#
#
# ...(360) Rimozione Piedistallo...
# ...Piedistallo Rimosso...
#
#
# ...(360) Calcolo del Segnale in Corrente e Rimozione degli Eventi Da Scartare...
# ...Calcolo & Rimozione Completati...
#
#
# ...CONTROLLO -> Eventi Eliminati da ../../../Data/PMTgem/selfPMTgemNew_360.root 6
#
#
# ...(360) Calcolo dell'Integrale di Carica...
# ...Calcolo Eseguito...
# ...(360) Calcolo del Valore Medio e Salvataggio...
# (17.9895020246924, 2.653833369618167)
# ---- Analisi su ../../../Data/PMTgem/selfPMTgemNew_360.root COMPLETATA! ----
#
#
# APERTURA di: ../../../Data/PMTgem/selfPMTgemNew_370.root
# ...(370) Caricamento Dati...
# ...Caricamento Dati Completato!...
#
#
# ...(370) Organizzazione Dati...
# ...Organizzazione Completata...
#
#
# ...Controllo Eventi Da Scartare...
# ...Eventi Scartati da ../../../Data/PMTgem/selfPMTgemNew_370.root: 5/1000
#
#
# ...(370) Rimozione Piedistallo...
# ...Piedistallo Rimosso...
#
#
# ...(370) Calcolo del Segnale in Corrente e Rimozione degli Eventi Da Scartare...
# ...Calcolo & Rimozione Completati...
#
#
# ...CONTROLLO -> Eventi Eliminati da ../../../Data/PMTgem/selfPMTgemNew_370.root 5
#
#
# ...(370) Calcolo dell'Integrale di Carica...
# ...Calcolo Eseguito...
# ...(370) Calcolo del Valore Medio e Salvataggio...
# (25.847792971808108, 2.6934127868619546)
# ---- Analisi su ../../../Data/PMTgem/selfPMTgemNew_370.root COMPLETATA! ----
#
#
# APERTURA di: ../../../Data/PMTgem/selfPMTgemNew_380.root
# ...(380) Caricamento Dati...
# ...Caricamento Dati Completato!...
#
#
# ...(380) Organizzazione Dati...
# ...Organizzazione Completata...
#
#
# ...Controllo Eventi Da Scartare...
# ...Eventi Scartati da ../../../Data/PMTgem/selfPMTgemNew_380.root: 6/1000
#
#
# ...(380) Rimozione Piedistallo...
# ...Piedistallo Rimosso...
#
#
# ...(380) Calcolo del Segnale in Corrente e Rimozione degli Eventi Da Scartare...
# ...Calcolo & Rimozione Completati...
#
#
# ...CONTROLLO -> Eventi Eliminati da ../../../Data/PMTgem/selfPMTgemNew_380.root 6
#
#
# ...(380) Calcolo dell'Integrale di Carica...
# ...Calcolo Eseguito...
# ...(380) Calcolo del Valore Medio e Salvataggio...
# (29.040156956209206, 2.6900188749533847)
# ---- Analisi su ../../../Data/PMTgem/selfPMTgemNew_380.root COMPLETATA! ----
#
#
# APERTURA di: ../../../Data/PMTgem/selfPMTgemNew_390.root
# ...(390) Caricamento Dati...
# ...Caricamento Dati Completato!...
#
#
# ...(390) Organizzazione Dati...
# ...Organizzazione Completata...
#
#
# ...Controllo Eventi Da Scartare...
# ...Eventi Scartati da ../../../Data/PMTgem/selfPMTgemNew_390.root: 8/1000
#
#
# ...(390) Rimozione Piedistallo...
# ...Piedistallo Rimosso...
#
#
# ...(390) Calcolo del Segnale in Corrente e Rimozione degli Eventi Da Scartare...
# ...Calcolo & Rimozione Completati...
#
#
# ...CONTROLLO -> Eventi Eliminati da ../../../Data/PMTgem/selfPMTgemNew_390.root 9
#
#
# ...(390) Calcolo dell'Integrale di Carica...
# ...Calcolo Eseguito...
# ...(390) Calcolo del Valore Medio e Salvataggio...
# (26.6716266499753, 3.070921855039535)
# ---- Analisi su ../../../Data/PMTgem/selfPMTgemNew_390.root COMPLETATA! ----
#
#
# APERTURA di: ../../../Data/PMTgem/selfPMTgemNew_400.root
# ...(400) Caricamento Dati...
# ...Caricamento Dati Completato!...
#
#
# ...(400) Organizzazione Dati...
# ...Organizzazione Completata...
#
#
# ...Controllo Eventi Da Scartare...
# ...Eventi Scartati da ../../../Data/PMTgem/selfPMTgemNew_400.root: 9/1000
#
#
# ...(400) Rimozione Piedistallo...
# ...Piedistallo Rimosso...
#
#
# ...(400) Calcolo del Segnale in Corrente e Rimozione degli Eventi Da Scartare...
# ...Calcolo & Rimozione Completati...
#
#
# ...CONTROLLO -> Eventi Eliminati da ../../../Data/PMTgem/selfPMTgemNew_400.root 9
#
#
# ...(400) Calcolo dell'Integrale di Carica...
# ...Calcolo Eseguito...
# ...(400) Calcolo del Valore Medio e Salvataggio...
# (21.852659944909075, 3.1015927826564784)
# ---- Analisi su ../../../Data/PMTgem/selfPMTgemNew_400.root COMPLETATA! ----
#
#
# APERTURA di: ../../../Data/PMTgem/selfPMTgemNew_410.root
# ...(410) Caricamento Dati...
# ...Caricamento Dati Completato!...
#
#
# ...(410) Organizzazione Dati...
# ...Organizzazione Completata...
#
#
# ...Controllo Eventi Da Scartare...
# ...Eventi Scartati da ../../../Data/PMTgem/selfPMTgemNew_410.root: 6/1000
#
#
# ...(410) Rimozione Piedistallo...
# ...Piedistallo Rimosso...
#
#
# ...(410) Calcolo del Segnale in Corrente e Rimozione degli Eventi Da Scartare...
# ...Calcolo & Rimozione Completati...
#
#
# ...CONTROLLO -> Eventi Eliminati da ../../../Data/PMTgem/selfPMTgemNew_410.root 7
#
#
# ...(410) Calcolo dell'Integrale di Carica...
# ...Calcolo Eseguito...
# ...(410) Calcolo del Valore Medio e Salvataggio...
# (9.981293052482341, 3.2461942239654147)
# ---- Analisi su ../../../Data/PMTgem/selfPMTgemNew_410.root COMPLETATA! ----
#
#
# APERTURA di: ../../../Data/PMTgem/selfPMTgemNew_420.root
# ...(420) Caricamento Dati...
# ...Caricamento Dati Completato!...
#
#
# ...(420) Organizzazione Dati...
# ...Organizzazione Completata...
#
#
# ...Controllo Eventi Da Scartare...
# ...Eventi Scartati da ../../../Data/PMTgem/selfPMTgemNew_420.root: 2/1000
#
#
# ...(420) Rimozione Piedistallo...
# ...Piedistallo Rimosso...
#
#
# ...(420) Calcolo del Segnale in Corrente e Rimozione degli Eventi Da Scartare...
# ...Calcolo & Rimozione Completati...
#
#
# ...CONTROLLO -> Eventi Eliminati da ../../../Data/PMTgem/selfPMTgemNew_420.root 3
#
#
# ...(420) Calcolo dell'Integrale di Carica...
# ...Calcolo Eseguito...
# ...(420) Calcolo del Valore Medio e Salvataggio...
# (10.80258275217867, 3.143370136295861)
# ---- Analisi su ../../../Data/PMTgem/selfPMTgemNew_420.root COMPLETATA! ----
#
#
# APERTURA di: ../../../Data/PMTgem/selfPMTgemNew_430.root
# ...(430) Caricamento Dati...
# ...Caricamento Dati Completato!...
#
#
# ...(430) Organizzazione Dati...
# ...Organizzazione Completata...
#
#
# ...Controllo Eventi Da Scartare...
# ...Eventi Scartati da ../../../Data/PMTgem/selfPMTgemNew_430.root: 7/1000
#
#
# ...(430) Rimozione Piedistallo...
# ...Piedistallo Rimosso...
#
#
# ...(430) Calcolo del Segnale in Corrente e Rimozione degli Eventi Da Scartare...
# ...Calcolo & Rimozione Completati...
#
#
# ...CONTROLLO -> Eventi Eliminati da ../../../Data/PMTgem/selfPMTgemNew_430.root 8
#
#
# ...(430) Calcolo dell'Integrale di Carica...
# ...Calcolo Eseguito...
# ...(430) Calcolo del Valore Medio e Salvataggio...
# (6.567867947311981, 3.201225180615844)
# ---- Analisi su ../../../Data/PMTgem/selfPMTgemNew_430.root COMPLETATA! ----
#
#
# APERTURA di: ../../../Data/PMTgem/selfPMTgemNew_440.root
# ...(440) Caricamento Dati...
# ...Caricamento Dati Completato!...
#
#
# ...(440) Organizzazione Dati...
# ...Organizzazione Completata...
#
#
# ...Controllo Eventi Da Scartare...
# ...Eventi Scartati da ../../../Data/PMTgem/selfPMTgemNew_440.root: 5/1000
#
#
# ...(440) Rimozione Piedistallo...
# ...Piedistallo Rimosso...
#
#
# ...(440) Calcolo del Segnale in Corrente e Rimozione degli Eventi Da Scartare...
# ...Calcolo & Rimozione Completati...
#
#
# ...CONTROLLO -> Eventi Eliminati da ../../../Data/PMTgem/selfPMTgemNew_440.root 6
#
#
# ...(440) Calcolo dell'Integrale di Carica...
# ...Calcolo Eseguito...
# ...(440) Calcolo del Valore Medio e Salvataggio...
# (5.004684105332139, 3.0955811698100764)
# ---- Analisi su ../../../Data/PMTgem/selfPMTgemNew_440.root COMPLETATA! ----
#
#
# APERTURA di: ../../../Data/PMTgem/selfPMTgemNew_450.root
# ...(450) Caricamento Dati...
# ...Caricamento Dati Completato!...
#
#
# ...(450) Organizzazione Dati...
# ...Organizzazione Completata...
#
#
# ...Controllo Eventi Da Scartare...
# ...Eventi Scartati da ../../../Data/PMTgem/selfPMTgemNew_450.root: 3/1000
#
#
# ...(450) Rimozione Piedistallo...
# ...Piedistallo Rimosso...
#
#
# ...(450) Calcolo del Segnale in Corrente e Rimozione degli Eventi Da Scartare...
# ...Calcolo & Rimozione Completati...
#
#
# ...CONTROLLO -> Eventi Eliminati da ../../../Data/PMTgem/selfPMTgemNew_450.root 4
#
#
# ...(450) Calcolo dell'Integrale di Carica...
# ...Calcolo Eseguito...
# ...(450) Calcolo del Valore Medio e Salvataggio...
# (5.766965862066077, 3.1740626056293273)
# ---- Analisi su ../../../Data/PMTgem/selfPMTgemNew_450.root COMPLETATA! ----
#
#
# ----- ANALISI GENERALE CONCLUSA!!!! ------
#  FCN=73.5863 FROM MIGRAD    STATUS=CONVERGED      80 CALLS          81 TOTAL
#                      EDM=2.98461e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     8.64395e+01   6.21953e+00   1.78971e-02   1.22538e-05
#    2  Mean         2.65383e+00   7.15535e-02   2.07106e-04  -1.55158e-02
#    3  Sigma        9.60003e-01   5.22676e-02   3.70105e-05   6.24403e-02
#  FCN=27.9557 FROM MIGRAD    STATUS=CONVERGED      66 CALLS          67 TOTAL
#                      EDM=7.28424e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     7.61123e+01   4.93421e+00   9.75766e-03  -7.81109e-07
#    2  Mean         2.69341e+00   7.11531e-02   1.60372e-04  -5.83343e-04
#    3  Sigma        1.14401e+00   5.61271e-02   2.97006e-05   4.22346e-04
#  FCN=15.2942 FROM MIGRAD    STATUS=CONVERGED      59 CALLS          60 TOTAL
#                      EDM=1.38062e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     9.94853e+01   5.63637e+00   8.50594e-03  -3.10349e-07
#    2  Mean         2.69002e+00   5.25130e-02   1.04149e-04   5.94446e-04
#    3  Sigma        1.07618e+00   4.23732e-02   1.90495e-05  -4.24896e-03
#  FCN=39.7491 FROM MIGRAD    STATUS=CONVERGED      67 CALLS          68 TOTAL
#                      EDM=2.08474e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.09750e+02   5.94797e+00   1.32530e-02  -5.62753e-07
#    2  Mean         3.07092e+00   5.88812e-02   1.61442e-04  -1.22445e-03
#    3  Sigma        1.22638e+00   5.15277e-02   2.84113e-05   1.80947e-03
#  FCN=44.3461 FROM MIGRAD    STATUS=CONVERGED      59 CALLS          60 TOTAL
#                      EDM=4.2233e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.23782e+02   6.16886e+00   1.56232e-02   1.70345e-05
#    2  Mean         3.10159e+00   5.85416e-02   1.59994e-04  -9.50217e-04
#    3  Sigma        1.11384e+00   4.09971e-02   2.60269e-05   8.63825e-03
#  FCN=60.0894 FROM MIGRAD    STATUS=CONVERGED      68 CALLS          69 TOTAL
#                      EDM=2.76068e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.13087e+02   6.07862e+00   1.61867e-02   1.47955e-05
#    2  Mean         3.24619e+00   5.99791e-02   1.89060e-04  -5.69066e-04
#    3  Sigma        1.26420e+00   5.24407e-02   3.25775e-05   4.14694e-03
#  FCN=56.7578 FROM MIGRAD    STATUS=CONVERGED      67 CALLS          68 TOTAL
#                      EDM=5.16935e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.32488e+02   6.40069e+00   1.77963e-02   4.30893e-06
#    2  Mean         3.14337e+00   4.76884e-02   1.60440e-04   5.30750e-03
#    3  Sigma        1.15357e+00   3.84369e-02   2.75407e-05   1.21416e-02
#  FCN=35.5189 FROM MIGRAD    STATUS=CONVERGED      60 CALLS          61 TOTAL
#                      EDM=2.91789e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.41121e+02   6.23753e+00   1.48999e-02   1.53942e-05
#    2  Mean         3.20123e+00   4.72487e-02   1.75695e-04   1.18715e-02
#    3  Sigma        1.11580e+00   3.26408e-02   2.15508e-05  -5.92559e-02
#  FCN=14.1394 FROM MIGRAD    STATUS=CONVERGED      66 CALLS          67 TOTAL
#                      EDM=7.56432e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.47853e+02   6.33527e+00   9.76273e-03   4.46460e-07
#    2  Mean         3.09558e+00   4.57900e-02   8.63067e-05   7.39547e-04
#    3  Sigma        1.14072e+00   3.31498e-02   1.43842e-05   7.01151e-04
#  FCN=16.7721 FROM MIGRAD    STATUS=CONVERGED      69 CALLS          70 TOTAL
#                      EDM=1.87959e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.47651e+02   6.28408e+00   1.06843e-02   3.16063e-06
#    2  Mean         3.17406e+00   5.15975e-02   1.46624e-04   1.39989e-04
#    3  Sigma        1.15928e+00   3.55514e-02   1.60712e-05  -4.93063e-03

# %%
plt.errorbar(np.array(hv) , np.array(means) , yerr = np.array(errors) , fmt = "*" , capsize = 5 , elinewidth = 1)

plt.grid()
plt.title('Th -10 mV')
plt.xlabel('$\Delta V_{GEM}$ [V]')
plt.ylabel('Mean Charge [pC]')
#plt.savefig('CaricaVsHVNewBoh.png')
plt.show()
